# %%
import sys
sys.path.append('.')
import numpy as np
import matplotlib.pyplot as plt
from map import CarMap

# %%
testmap = CarMap(visualize=True)
scanlist = [30, 30, 30, 30, 30, 130, 30, 30, 30]
testmap.constructMap(scanlist)
testmap.printMap()

# %%
testmap.extendMap(width=3)
testmap.printMap()
